# %% [markdown]
# # Matplotlib examples

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels as sm
from IPython.core.pylabtools import figsize
from sklearn import datasets

# %matplotlib inline
figsize(6, 6)

# %% [markdown]
# # Big picture
#
# Reference: https://brohrer.github.io/matplotlib_going_deeper.html
#
# 1. Figures hold Axes
# 2. Axes hold almost everything else
# 3. Backends do the heavy lifting
#
# > "The name "Axes" is a little misleading. An Axes object contains both an x-axis and a y-axis (which are objects in their own right), as well as lines, patches, text annotations, and the region in which these are displayed. Throughout these examples, I'll try to be consistent about referring to an Axes object as Axes and an x- and y-axis pair as axes, lowercase."
#
#
# ## Two separate layers of Matlplotlib
# This post gives some background: http://www.aosabook.org/en/matplotlib.html
#
# When you write code using the `Artist` layer, you usually start with `fig, ax = plt.subplots()`
#
# When writing using the scripting layer, you write stuff like `plt.hist()`
#
# Although the scripting approach is quicker off the ground, it won't work well for customizations.
#
# Again from [this link](https://brohrer.github.io/matplotlib_going_deeper.html):
#
# > To keep things as clean as possible in our code examples, we will usually work directly with the Figure and Axes objects, rather than using the pyplot simplifications that gloss over them. It turns out that if we want to do much customization, this makes our job a lot easier.
#
# > Matplotlib has several ways to do most things, and while this can provide convenience, it can also create a lot of confusion. We will stick to one way of doing things, usually the one that most clearly reflects the underlying structure, rather than the one that results in the shortest code. This also gives us fewer things to remember.

# %%
x = np.random.randn(10000)

# %%
fig, ax = plt.subplots()  
# try "type(plt.subplots())" - you'll see that it returns a tuple. This is unpacked and bound to the fig and ax variables. 

# Note that type(plt.subplot()) does not return a tuple, and so can't be unpacked into fig and ax. 

ax.hist(x, 100)  # use hist() method of the axis instance to show a histogram 
ax.set_title('Normal distribution with $\mu=0, \sigma=1$')
# Out:
# Text(0.5,1,'Normal distribution with $\\mu=0, \\sigma=1$')

# %%
# now do the same with the scripting layer: 

plt.hist(x, 100)  # you may have to scroll to see the plot
# Out:
# (array([  2.,   1.,   0.,   0.,   1.,   0.,   2.,   1.,   2.,   2.,   3.,
#           0.,   3.,  10.,   5.,   2.,  11.,   8.,  15.,  21.,  19.,  26.,
#          35.,  27.,  33.,  42.,  54.,  63.,  76.,  84.,  85., 101., 115.,
#         134., 137., 158., 154., 186., 199., 218., 202., 217., 207., 253.,
#         250., 259., 312., 270., 283., 288., 286., 327., 315., 269., 301.,
#         306., 294., 282., 258., 252., 202., 216., 222., 194., 182., 146.,
#         160., 150., 136., 129., 119.,  89.,  75.,  64.,  75.,  64.,  44.,
#          34.,  42.,  31.,  30.,  22.,  28.,  19.,  15.,  13.,   4.,   5.,
#           6.,   5.,   6.,   1.,   3.,   1.,   1.,   0.,   0.,   0.,   0.,
#           1.]),
#  array([-3.87547734, -3.79973006, -3.72398278, -3.6482355 , -3.57248821,
#         -3.49674093, -3.42099365, -3.34524637, -3.26949908, -3.1937518 ,
#         -3.11800452, -3.04225724, -2.96650995, -2.89076267, -2.81501539,
#         -2.73926811, -2.66352083, -2.58777354, -2.51202626, -2.43627898,
#         -2.3605317 , -2.28478441, -2.20903713, -2.13328985, -2.05754257,
#         -1.98179528, -1.906048  , -1.83030072, -1.75455344, -1.67880616,
#         -1.60305887, -1.52731159, -1.45156431, -1.37581703, -1.30006974,
#         -1.22432246, -1.14857518, -1.0728279 , -0.99708061, -0.92133333,
#         -0.84558605, -0.76983877, -0.69409149, -0.6183442 , -0.54259692,
#         -0.46684964, -0.39110236, -0.31535507, -0.23960779, -0.16386051,
#         -0.08811323, -0.01236594,  0.06338134,  0.13912862,  0.2148759 ,
#          0.29062318,  0.36637047,  0.44211775,  0.51786503,  0.59361231,
#          0.6693596 ,  0.74510688,  0.82085416,  0.89660144,  0.97234873,
#          1.04809601,  1.12384329,  1.19959057,  1.27533786,  1.35108514,
#          1.42683242,  1.5025797 ,  1.57832698,  1.65407427,  1.72982155,
#          1.80556883,  1.88131611,  1.9570634 ,  2.03281068,  2.10855796,
#          2.18430524,  2.26005253,  2.33579981,  2.41154709,  2.48729437,
#          2.56304165,  2.63878894,  2.71453622,  2.7902835 ,  2.86603078,
#          2.94177807,  3.01752535,  3.09327263,  3.16901991,  3.2447672 ,
#          3.32051448,  3.39626176,  3.47200904,  3.54775632,  3.62350361,
#          3.69925089]),
#  <a list of 100 Patch objects>)

# %% [markdown]
# # Eg 1: Separate line plots with shared x-axis
#
# https://matplotlib.org/3.1.1/gallery/subplots_axes_and_figures/shared_axis_demo.html#sphx-glr-gallery-subplots-axes-and-figures-shared-axis-demo-py

# %%
t = np.arange(0.01, 5.0, 0.01)
s1 = np.sin(2 * np.pi * t)
s2 = np.exp(-t)
s3 = np.sin(4 * np.pi * t)

# %%
# type(s1)  # numpy.ndarray

# %% [markdown]
# Most real data will come in DataFrames, so let's create a df for this.

# %%
df1 = pd.DataFrame({'sin_fn':s1, 'exp_fn':s2}, index = t)

# %%
df1.head()
# Out:
#         sin_fn    exp_fn
# 0.01  0.062791  0.990050
# 0.02  0.125333  0.980199
# 0.03  0.187381  0.970446
# 0.04  0.248690  0.960789
# 0.05  0.309017  0.951229

# %%
# df1.columns

# %%
# df1.index

# %%
ax1 = plt.subplot(211)  # 2 rows, 1 col, start plotting at index 1
plt.plot(df1['sin_fn'])

ax2 = plt.subplot(212, sharex=ax1)  # 2 rows, 1 col, start at index 2
plt.plot(df1['exp_fn'])

# %% [markdown]
# Note that we could have plotted these as part of the same plot as below:

# %%
plt.plot(df1['sin_fn'])
plt.plot(df1['exp_fn'])

# %% [markdown]
# # Eg 2: Histogram

# %%
x = np.random.poisson(10, 5000)

df = pd.DataFrame({'pois_var':x})

# %%
# plt.subplot(111)
plt.hist(df['pois_var'], bins=12)
plt.title('histogram')
# Out:
# Text(0.5,1,'histogram')

# %%
# alternative method: 

fig, ax = plt.subplots()

ax.hist(df['pois_var'], 10)
ax.set_title("hist")
# Out:
# Text(0.5,1,'hist')

# %% [markdown]
# # Eg 3: Scatter plot with iris data

# %%
iris_dataset = datasets.load_iris() 
df = pd.DataFrame(data= np.c_[iris_dataset['data'], iris_dataset['target']],
                     columns= iris_dataset['feature_names'] + ['target'])

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df['target'].value_counts()  # same as table() in R
# Out:
# 2.0    50
# 1.0    50
# 0.0    50
# Name: target, dtype: int64

# %%
fig, ax = plt.subplots()

ax.scatter(df['sepal length (cm)'], df['petal length (cm)'])

ax.set_title('sepal vs petal length')
ax.set_xlabel('sepal')
ax.set_ylabel('petal')
# Out:
# Text(0,0.5,'petal')

# %% [markdown]
# What if we want to colour points based on value of the `target` column?
#
# Ans. It's going to be ugly.
#
# Ref: https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60

# %%
# set up mapping between values of df['target'] and colours to plot: 
targets = df.target.unique().tolist()  # will give [0, 1, 2]
colors = ['r', 'g', 'b']
# zip(targets, colors)  # returns a zip operator - a type of iterator. Specifically, it's an iterator that returns a tuple in each "pass"




# Start plotting --------------------------------------
fig, ax = plt.subplots()

# use a for loop to: 
# 1. subset the df for all red points, and pass it to ax.scatter() 
# 2. subset the df for all blue points, ... 
# 3. subset the def for all green points, ...

for target, color in zip(targets,colors):
    indicesToKeep = df['target'] == target  # returns a boolean Series 
    ax.scatter(df.loc[indicesToKeep, 'sepal length (cm)']
               , df.loc[indicesToKeep, 'petal length (cm)']
               , c = color
               , s = 50)


ax.set_title('sepal vs petal length')
ax.set_xlabel('sepal')
ax.set_ylabel('petal')
# Out:
# Text(0,0.5,'petal')
