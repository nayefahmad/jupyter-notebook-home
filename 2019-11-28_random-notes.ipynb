# %% [markdown]
# # Playing with pandas Series objects

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels as sm
from IPython.core.pylabtools import figsize

# %matplotlib inline
figsize(6, 6)

# %%
x1 = pd.Series([1,2,3,12,50])
x2 = pd.Series(['a', 'b', 'c'], index=['first', 'second', 'third'])
x3 = pd.Series([1, 'b', 'c'])
x4 = pd.Series([98, 80, 100, 97, 85])

# %%
x1
# Out:
# 0     1
# 1     2
# 2     3
# 3    12
# 4    50
# dtype: int64

# %%
x2
# Out:
# first     a
# second    b
# third     c
# dtype: object

# %%
x3
# Out:
# 0    1
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# Pandas series have two key components:
#
# 1. Index
# 2. Values

# %%
x1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
x1.values
# Out:
# array([ 1,  2,  3, 12, 50], dtype=int64)

# %%
x2.index
# Out:
# Index(['first', 'second', 'third'], dtype='object')

# %%
# reindex can be used to reorder values using their inexes 
x5 = x3.reindex([0, 1, 2])
x5
# Out:
# 0    1
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# # Subsetting

# %%
x2.index
# Out:
# Index(['first', 'second', 'third'], dtype='object')

# %%
# We'll subset the Series with boolean Series
x1 > 2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
type(x1 > 2)
# Out:
# pandas.core.series.Series

# %%
x1[x1 > 2]
# Out:
# 2     3
# 3    12
# 4    50
# dtype: int64

# %%
# Does the number 3 appear in the index of x2? 
'first' in x2
# Out:
# True

# %%
'third' in x2
# Out:
# True

# %% [markdown]
# # Plotting
#
# ## Single line plot from a Series object.

# %%
plt.plot(x1)
plt.title('Line plot - plt.plot(pd_series_object)')
# Out:
# Text(0.5,1,'Line plot - plt.plot(pd_series_object)')

# %% [markdown]
# In VS Code, you can double click the plot, and it will open in a separate tab, along with other added plots.

# %% [markdown]
# ## Several line plots using Series objects

# %%
plt.plot(x1)
plt.plot(x4)
plt.plot(pd.Series([60, 59, 58, 90, 60]))
plt.title('Several line plots')
# Out:
# Text(0.5,1,'Several line plots')

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(x1, x4)
plt.title('A scatter plot')
plt.ylim(75, 110)
# Out:
# (75, 110)
